# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %% [markdown]
# ## 1. Color selection

# %%
image = mpimg.imread('images/test.jpg')
print(image.shape)
plt.imshow(image)
# Out:
# (720, 1280, 3)

# %%
ysize = image.shape[0]
xsize = image.shape[1]
color_select = np.copy(image)

# %%
red_threshold = 200
green_threshold = 200
blue_threshold = 200

# %%
rgb_threshold = [red_threshold, green_threshold, blue_threshold]

# %%
# any of r/g/b that below r/g/b_threshold will be selected to be "True" 
# so later we set them as 0 or using "~color_thresholds" to retain where > b_threshold
color_thresholds = (image[:,:,0] < rgb_threshold[0]) \
            | (image[:,:,1] < rgb_threshold[1]) \
            | (image[:,:,2] < rgb_threshold[2])
print(color_thresholds.shape)
# This will generate a mask
print(image[:, :, 2] < rgb_threshold[0])
# Out:
# (720, 1280)
# [[False  True  True ...  True  True  True]
#  [ True  True False ... False  True  True]
#  [ True False False ... False False  True]
#  ...
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]]

# %%
# Apply the mask to image, and set [0, 0, 0] for "false" position
color_select[color_thresholds] = [0,0,0]
print(color_select.shape)
# Out:
# (720, 1280, 3)

# %%
plt.imshow(color_select)

# %% [markdown]
# ## 2. Region masking

# %%
region_select = np.copy(image)
print(region_select.shape)
left_bottom = [0, 719]
right_bottom = [1280, 719]
apex = [640, 400]
# Out:
# (720, 1280, 3)

# %%
# Fit lines (y=Ax+B) to identify the  3 sided region of interest
# np.polyfit() returns the coefficients [A, B] of the fit
fit_left = np.polyfit((left_bottom[0], apex[0]), (left_bottom[1], apex[1]), 1)
fit_right = np.polyfit((right_bottom[0], apex[0]), (right_bottom[1], apex[1]), 1)
fit_bottom = np.polyfit((left_bottom[0], right_bottom[0]), (left_bottom[1], right_bottom[1]), 1)

# %%
# Find the region inside the lines
XX, YY = np.meshgrid(np.arange(0, xsize), np.arange(0, ysize))
region_thresholds = (YY > (XX*fit_left[0] + fit_left[1])) & \
                    (YY > (XX*fit_right[0] + fit_right[1])) & \
                    (YY < (XX*fit_bottom[0] + fit_bottom[1]))

# %%
# Color pixels red which are inside the region of interest
region_select[region_thresholds] = [255, 0, 0]

# %%
plt.imshow(region_select)

# %% [markdown]
# ## Combining Color and Region Selections

# %%
image_select = np.copy(image)

# %%
# combine color_thresholds and region_thresholds
image_select[~color_thresholds & region_thresholds] = [255, 0, 0]

# %%
plt.imshow(image_select)
